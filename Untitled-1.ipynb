# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus
from dotenv import load_dotenv

load_dotenv()

password = quote_plus(os.getenv("DB_PASSWORD"))
user     = os.getenv("DB_USER")
db       = os.getenv("DB_NAME")

engine = create_engine(
    f"postgresql+psycopg2://{user}:{password}@localhost:5432/{db}"
)

# Query di esempio — tutti i passaggi accurati di una squadra
query = """
SELECT DISTINCT match_id, match_date, 
       MIN(team_name) AS squadra_casa,
       MAX(team_name) AS squadra_trasferta
FROM eventi
GROUP BY match_id, match_date
ORDER BY match_date DESC
LIMIT 10;
"""

df = pd.read_sql(query, engine)
print(df.shape)
df.head()
# Out:
# (10, 4)
#    match_id  match_date squadra_casa squadra_trasferta
# 0   1901165  2026-03-16    Cremonese        Fiorentina
# 1   1901181  2026-03-15        Genoa            Verona
# 2   1901175  2026-03-15      Bologna          Sassuolo
# 3   1901399  2026-03-15         Como              Roma
# 4   1901169  2026-03-15     AC Milan             Lazio
